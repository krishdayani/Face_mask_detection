# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import cv2
from keras.layers import Flatten, Dense
from keras.applications.vgg16 import VGG16

# %%
mask_data_train = 'Face Mask Dataset/Train'
mask_data_test = 'Face Mask Dataset/Test'
val_data_train = 'Face Mask Dataset/Validation'

# %%
img_width = 150
img_height = 150

# %%
data_train = tf.keras.utils.image_dataset_from_directory(mask_data_train,
                                                        shuffle=True, 
                                                        image_size=(img_width, img_height),
                                                        batch_size=32, 
                                                        validation_split=False)
# Out:
# Found 20815 files belonging to 2 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(mask_data_test,
                                                        shuffle=True, 
                                                        image_size=(img_width, img_height),
                                                        batch_size=32, 
                                                        validation_split=False)
# Out:
# Found 992 files belonging to 2 classes.

# %%
val_train = tf.keras.utils.image_dataset_from_directory(val_data_train,
                                                        shuffle=True, 
                                                        image_size=(img_width, img_height),
                                                        batch_size=32, 
                                                        validation_split=False)
# Out:
# Found 800 files belonging to 2 classes.

# %%
data_cat = data_train.class_names
data_cat
# Out:
# ['WithMask', 'WithoutMask']

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
CN_bas = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(150,150,3)
)

# %%
CN_bas.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = Sequential()
model.add(CN_bas)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,812,353 (64.13 MB)
#  Trainable params: 16,812,353 (64.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
CN_bas.trainable = False

# %%
def process(image, label):
    image = tf.cast(image/255. , tf.float32)
    return image, label
data_train = data_train.map(process)
val_train = val_train.map(process)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00001), 
            loss = keras.losses.BinaryCrossentropy(), metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
epochs = 30
history = model.fit(data_train,validation_data=val_train, epochs = epochs)
# Out:
# Epoch 1/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 785s 1s/step - accuracy: 0.9228 - loss: 0.2329 - val_accuracy: 0.9725 - val_loss: 0.0979
# Epoch 2/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 913s 1s/step - accuracy: 0.9699 - loss: 0.0942 - val_accuracy: 0.9787 - val_loss: 0.0686
# Epoch 3/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 859s 1s/step - accuracy: 0.9761 - loss: 0.0738 - val_accuracy: 0.9787 - val_loss: 0.0569
# Epoch 4/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 883s 1s/step - accuracy: 0.9797 - loss: 0.0630 - val_accuracy: 0.9812 - val_loss: 0.0491
# Epoch 5/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 1027s 2s/step - accuracy: 0.9823 - loss: 0.0553 - val_accuracy: 0.9850 - val_loss: 0.0406
# Epoch 6/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 981s 2s/step - accuracy: 0.9848 - loss: 0.0497 - val_accuracy: 0.9862 - val_loss: 0.0376
# Epoch 7/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 846s 1s/step - accuracy: 0.9862 - loss: 0.0450 - val_accuracy: 0.9875 - val_loss: 0.0379
# Epoch 8/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 721s 1s/step - accuracy: 0.9879 - loss: 0.0408 - val_accuracy: 0.9912 - val_loss: 0.0306
# Epoch 9/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 752s 1s/step - accuracy: 0.9895 - loss: 0.0374 - val_accuracy: 0.9912 - val_loss: 0.0286
# Epoch 10/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 744s 1s/step - accuracy: 0.9908 - loss: 0.0344 - val_accuracy: 0.9912 - val_loss: 0.0278
# Epoch 11/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 709s 1s/step - accuracy: 0.9920 - loss: 0.0318 - val_accuracy: 0.9912 - val_loss: 0.0255
# Epoch 12/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 686s 1s/step - accuracy: 0.9924 - loss: 0.0293 - val_accuracy: 0.9912 - val_loss: 0.0258
# Epoch 13/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 681s 1s/step - accuracy: 0.9933 - loss: 0.0270 - val_accuracy: 0.9912 - val_loss: 0.0275
# Epoch 14/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 682s 1s/step - accuracy: 0.9937 - loss: 0.0250 - val_accuracy: 0.9937 - val_loss: 0.0222
# Epoch 15/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 1472s 2s/step - accuracy: 0.9942 - loss: 0.0230 - val_accuracy: 0.9925 - val_loss: 0.0238
# Epoch 16/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 807s 1s/step - accuracy: 0.9950 - loss: 0.0213 - val_accuracy: 0.9925 - val_loss: 0.0235
# Epoch 17/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 852s 1s/step - accuracy: 0.9957 - loss: 0.0199 - val_accuracy: 0.9925 - val_loss: 0.0238
# Epoch 18/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 823s 1s/step - accuracy: 0.9962 - loss: 0.0186 - val_accuracy: 0.9925 - val_loss: 0.0227
# Epoch 19/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 838s 1s/step - accuracy: 0.9967 - loss: 0.0172 - val_accuracy: 0.9937 - val_loss: 0.0205
# Epoch 20/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 768s 1s/step - accuracy: 0.9972 - loss: 0.0160 - val_accuracy: 0.9937 - val_loss: 0.0188
# Epoch 21/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 739s 1s/step - accuracy: 0.9981 - loss: 0.0145 - val_accuracy: 0.9937 - val_loss: 0.0181
# Epoch 22/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 727s 1s/step - accuracy: 0.9981 - loss: 0.0137 - val_accuracy: 0.9962 - val_loss: 0.0160
# Epoch 23/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 732s 1s/step - accuracy: 0.9986 - loss: 0.0126 - val_accuracy: 0.9950 - val_loss: 0.0189
# Epoch 24/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 741s 1s/step - accuracy: 0.9988 - loss: 0.0117 - val_accuracy: 0.9962 - val_loss: 0.0155
# Epoch 25/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 749s 1s/step - accuracy: 0.9990 - loss: 0.0108 - val_accuracy: 0.9962 - val_loss: 0.0154
# Epoch 26/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 743s 1s/step - accuracy: 0.9993 - loss: 0.0101 - val_accuracy: 0.9937 - val_loss: 0.0193
# Epoch 27/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 728s 1s/step - accuracy: 0.9993 - loss: 0.0093 - val_accuracy: 0.9950 - val_loss: 0.0185
# Epoch 28/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 728s 1s/step - accuracy: 0.9993 - loss: 0.0086 - val_accuracy: 0.9962 - val_loss: 0.0160
# Epoch 29/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 740s 1s/step - accuracy: 0.9995 - loss: 0.0080 - val_accuracy: 0.9962 - val_loss: 0.0162
# Epoch 30/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 739s 1s/step - accuracy: 0.9995 - loss: 0.0074 - val_accuracy: 0.9950 - val_loss: 0.0162

# %%
epoch_range = range(epochs)
plt.figure(figsize=(8,8))

# %%
image = '1.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_width, img_height))
img_arr = tf.keras.utils.array_to_img(image)
img_bat = tf.expand_dims(img_arr, 0)

# %%
plt.imshow(image)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step

# %%
score = tf.math.sigmoid(predict)

# %%
score
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.5]], dtype=float32)>

# %%
cap = cv2.VideoCapture(0)

# %%
def detect_face_mask(img):
    img_resized = cv2.resize(img, (150, 150))
    img_bat = np.expand_dims(img_resized, axis=0)
    prediction = model.predict(img_bat, verbose=0)[0][0]
    if prediction >0.5:
        return 1
    else:
        return 0

# %%
def draw_label(img, text, pos, bg_color):
    text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 1, cv2.FILLED)
    end_x = pos[0] + text_size[0][0] + 2
    end_y = pos[1] + text_size[0][1] - 2

    cv2.rectangle(img, pos, (end_x, end_y), bg_color, cv2.FILLED)
    cv2.putText(img, text, pos, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 1, cv2.LINE_AA)

# %%
haar = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    cood = haar.detectMultiScale(img)
    return cood

# %%
while True:
    ret, frame = cap.read()

    coods = detect_face(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
    for x,y,w,h in coods:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,0), 2)
    
    frame = cv2.resize(frame,(224, 224))
    y_pred = detect_face_mask(frame)
    if y_pred == 0:
        draw_label(frame, "Mask", (30, 30), (0, 255, 0))
    else:
        draw_label(frame, "No Mask", (30, 30), (0, 0, 255))
    cv2.imshow("window", frame)
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
cv2.destroyAllWindows()
